# %% [markdown]
# Importing Libraries 📚

# %%
# Importing libraries that will be used in this Notebook.
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Data Collection & Processing

# %%
# Loading the csv data to a Pandas Dataframe
gold_data = pd.read_csv(r"C:\Users\Manar\Downloads\gld_price_data (1).csv")

# %%
gold_data
# Out:
#            Date          SPX         GLD        USO      SLV   EUR/USD
# 0      1/2/2008  1447.160034   84.860001  78.470001  15.1800  1.471692
# 1      1/3/2008  1447.160034   85.570000  78.370003  15.2850  1.474491
# 2      1/4/2008  1411.630005   85.129997  77.309998  15.1670  1.475492
# 3      1/7/2008  1416.180054   84.769997  75.500000  15.0530  1.468299
# 4      1/8/2008  1390.189941   86.779999  76.059998  15.5900  1.557099
# ...         ...          ...         ...        ...      ...       ...
# 2285   5/8/2018  2671.919922  124.589996  14.060000  15.5100  1.186789
# 2286   5/9/2018  2697.790039  124.330002  14.370000  15.5300  1.184722
# 2287  5/10/2018  2723.070068  125.180000  14.410000  15.7400  1.191753
# 2288  5/14/2018  2730.129883  124.489998  14.380000  15.5600  1.193118
# 2289  5/16/2018  2725.780029  122.543800  14.405800  15.4542  1.182033
#
# [2290 rows x 6 columns]

# %%
# first 5 rows of the dataframe
gold_data.head()
# Out:
#        Date          SPX        GLD        USO     SLV   EUR/USD
# 0  1/2/2008  1447.160034  84.860001  78.470001  15.180  1.471692
# 1  1/3/2008  1447.160034  85.570000  78.370003  15.285  1.474491
# 2  1/4/2008  1411.630005  85.129997  77.309998  15.167  1.475492
# 3  1/7/2008  1416.180054  84.769997  75.500000  15.053  1.468299
# 4  1/8/2008  1390.189941  86.779999  76.059998  15.590  1.557099

# %%
#Using hide_index() from the style function
gold_data.head()
# Out:
#        Date          SPX        GLD        USO     SLV   EUR/USD
# 0  1/2/2008  1447.160034  84.860001  78.470001  15.180  1.471692
# 1  1/3/2008  1447.160034  85.570000  78.370003  15.285  1.474491
# 2  1/4/2008  1411.630005  85.129997  77.309998  15.167  1.475492
# 3  1/7/2008  1416.180054  84.769997  75.500000  15.053  1.468299
# 4  1/8/2008  1390.189941  86.779999  76.059998  15.590  1.557099

# %%
#Gradient background color for the numerical columns
gold_data.head(10).style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_84b0f_row0_col1, #T_84b0f_row0_col3, #T_84b0f_row1_col1, #T_84b0f_row4_col5, #T_84b0f_row8_col2, #T_84b0f_row8_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_84b0f_row0_col2 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_84b0f_row0_col4 {
#   background-color: #fee4d8;
#   color: #000000;
# }
# #T_84b0f_row0_col5 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_84b0f_row1_col2 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_84b0f_row1_col3 {
#   background-color: #6f020e;
#   color: #f1f1f1;
# }
# #T_84b0f_row1_col4 {
#   background-color: #fdcdb9;
#   color: #000000;
# }
# #T_84b0f_row1_col5 {
#   background-color: #fee7db;
#   color: #000000;
# }
# #T_84b0f_row2_col1 {
#   background-color: #fb7656;
#   color: #f1f1f1;
# }
# #T_84b0f_row2_col2 {
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_84b0f_row2_col3 {
#   background-color: #bd151a;
#   color: #f1f1f1;
# }
# #T_84b0f_row2_col4 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_84b0f_row2_col5 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_84b0f_row3_col1, #T_84b0f_row8_col1 {
#   background-color: #f85d42;
#   color: #f1f1f1;
# }
# #T_84b0f_row3_col2, #T_84b0f_row3_col4, #T_84b0f_row5_col5, #T_84b0f_row9_col1, #T_84b0f_row9_col3 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_84b0f_row3_col3 {
#   background-color: #fb7151;
#   color: #f1f1f1;
# }
# #T_84b0f_row3_col5 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_84b0f_row4_col1, #T_84b0f_row7_col5 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_84b0f_row4_col2 {
#   background-color: #fc8464;
#   color: #f1f1f1;
# }
# #T_84b0f_row4_col3 {
#   background-color: #f44d38;
#   color: #f1f1f1;
# }
# #T_84b0f_row4_col4 {
#   background-color: #fb7d5d;
#   color: #f1f1f1;
# }
# #T_84b0f_row5_col1 {
#   background-color: #fc8262;
#   color: #f1f1f1;
# }
# #T_84b0f_row5_col2 {
#   background-color: #fc9373;
#   color: #000000;
# }
# #T_84b0f_row5_col3 {
#   background-color: #fc7f5f;
#   color: #f1f1f1;
# }
# #T_84b0f_row5_col4 {
#   background-color: #fc9070;
#   color: #000000;
# }
# #T_84b0f_row6_col1 {
#   background-color: #f24633;
#   color: #f1f1f1;
# }
# #T_84b0f_row6_col2 {
#   background-color: #d11e1f;
#   color: #f1f1f1;
# }
# #T_84b0f_row6_col3 {
#   background-color: #fdc5ae;
#   color: #000000;
# }
# #T_84b0f_row6_col4 {
#   background-color: #b51318;
#   color: #f1f1f1;
# }
# #T_84b0f_row6_col5, #T_84b0f_row9_col5 {
#   background-color: #fed9c9;
#   color: #000000;
# }
# #T_84b0f_row7_col1 {
#   background-color: #fcaa8d;
#   color: #000000;
# }
# #T_84b0f_row7_col2 {
#   background-color: #bc141a;
#   color: #f1f1f1;
# }
# #T_84b0f_row7_col3 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_84b0f_row7_col4 {
#   background-color: #b11218;
#   color: #f1f1f1;
# }
# #T_84b0f_row8_col3 {
#   background-color: #fcb89e;
#   color: #000000;
# }
# #T_84b0f_row8_col5 {
#   background-color: #fcc3ab;
#   color: #000000;
# }
# #T_84b0f_row9_col2 {
#   background-color: #e12d26;
#   color: #f1f1f1;
# }
# #T_84b0f_row9_col4 {
#   background-color: #ec382b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_84b0f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84b0f_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_84b0f_level0_col1" class="col_heading level0 col1" >SPX</th>
#       <th id="T_84b0f_level0_col2" class="col_heading level0 col2" >GLD</th>
#       <th id="T_84b0f_level0_col3" class="col_heading level0 col3" >USO</th>
#       <th id="T_84b0f_level0_col4" class="col_heading level0 col4" >SLV</th>
#       <th id="T_84b0f_level0_col5" class="col_heading level0 col5" >EUR/USD</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84b0f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_84b0f_row0_col0" class="data row0 col0" >1/2/2008</td>
#       <td id="T_84b0f_row0_col1" class="data row0 col1" >1447.160034</td>
#       <td id="T_84b0f_row0_col2" class="data row0 col2" >84.860001</td>
#       <td id="T_84b0f_row0_col3" class="data row0 col3" >78.470001</td>
#       <td id="T_84b0f_row0_col4" class="data row0 col4" >15.180000</td>
#       <td id="T_84b0f_row0_col5" class="data row0 col5" >1.471692</td>
#     </tr>
#     <tr>
#       <th id="T_84b0f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_84b0f_row1_col0" class="data row1 col0" >1/3/2008</td>
#       <td id="T_84b0f_row1_col1" class="data row1 col1" >1447.160034</td>
#       <td id="T_84b0f_row1_col2" class="data row1 col2" >85.570000</td>
#       <td id="T_84b0f_row1_col3" class="data row1 col3" >78.370003</td>
#       <td id="T_84b0f_row1_col4" class="data row1 col4" >15.285000</td>
#       <td id="T_84b0f_row1_col5" class="data row1 col5" >1.474491</td>
#     </tr>
#     <tr>
#       <th id="T_84b0f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_84b0f_row2_col0" class="data row2 col0" >1/4/2008</td>
#       <td id="T_84b0f_row2_col1" class="data row2 col1" >1411.630005</td>
#       <td id="T_84b0f_row2_col2" class="data row2 col2" >85.129997</td>
#       <td id="T_84b0f_row2_col3" class="data row2 col3" >77.309998</td>
#       <td id="T_84b0f_row2_col4" class="data row2 col4" >15.167000</td>
#       <td id="T_84b0f_row2_col5" class="data row2 col5" >1.475492</td>
#     </tr>
#     <tr>
#       <th id="T_84b0f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_84b0f_row3_col0" class="data row3 col0" >1/7/2008</td>
#       <td id="T_84b0f_row3_col1" class="data row3 col1" >1416.180054</td>
#       <td id="T_84b0f_row3_col2" class="data row3 col2" >84.769997</td>
#       <td id="T_84b0f_row3_col3" class="data row3 col3" >75.500000</td>
#       <td id="T_84b0f_row3_col4" class="data row3 col4" >15.053000</td>
#       <td id="T_84b0f_row3_col5" class="data row3 col5" >1.468299</td>
#     </tr>
#     <tr>
#       <th id="T_84b0f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_84b0f_row4_col0" class="data row4 col0" >1/8/2008</td>
#       <td id="T_84b0f_row4_col1" class="data row4 col1" >1390.189941</td>
#       <td id="T_84b0f_row4_col2" class="data row4 col2" >86.779999</td>
#       <td id="T_84b0f_row4_col3" class="data row4 col3" >76.059998</td>
#       <td id="T_84b0f_row4_col4" class="data row4 col4" >15.590000</td>
#       <td id="T_84b0f_row4_col5" class="data row4 col5" >1.557099</td>
#     </tr>
#     <tr>
#       <th id="T_84b0f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_84b0f_row5_col0" class="data row5 col0" >1/9/2008</td>
#       <td id="T_84b0f_row5_col1" class="data row5 col1" >1409.130005</td>
#       <td id="T_84b0f_row5_col2" class="data row5 col2" >86.550003</td>
#       <td id="T_84b0f_row5_col3" class="data row5 col3" >75.250000</td>
#       <td id="T_84b0f_row5_col4" class="data row5 col4" >15.520000</td>
#       <td id="T_84b0f_row5_col5" class="data row5 col5" >1.466405</td>
#     </tr>
#     <tr>
#       <th id="T_84b0f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_84b0f_row6_col0" class="data row6 col0" >1/10/2008</td>
#       <td id="T_84b0f_row6_col1" class="data row6 col1" >1420.329956</td>
#       <td id="T_84b0f_row6_col2" class="data row6 col2" >88.250000</td>
#       <td id="T_84b0f_row6_col3" class="data row6 col3" >74.019997</td>
#       <td id="T_84b0f_row6_col4" class="data row6 col4" >16.061001</td>
#       <td id="T_84b0f_row6_col5" class="data row6 col5" >1.480100</td>
#     </tr>
#     <tr>
#       <th id="T_84b0f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_84b0f_row7_col0" class="data row7 col0" >1/11/2008</td>
#       <td id="T_84b0f_row7_col1" class="data row7 col1" >1401.020020</td>
#       <td id="T_84b0f_row7_col2" class="data row7 col2" >88.580002</td>
#       <td id="T_84b0f_row7_col3" class="data row7 col3" >73.089996</td>
#       <td id="T_84b0f_row7_col4" class="data row7 col4" >16.077000</td>
#       <td id="T_84b0f_row7_col5" class="data row7 col5" >1.479006</td>
#     </tr>
#     <tr>
#       <th id="T_84b0f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_84b0f_row8_col0" class="data row8 col0" >1/14/2008</td>
#       <td id="T_84b0f_row8_col1" class="data row8 col1" >1416.250000</td>
#       <td id="T_84b0f_row8_col2" class="data

# %%
# last 5 rows of the dataframe
gold_data.tail()
# Out:
#            Date          SPX         GLD      USO      SLV   EUR/USD
# 2285   5/8/2018  2671.919922  124.589996  14.0600  15.5100  1.186789
# 2286   5/9/2018  2697.790039  124.330002  14.3700  15.5300  1.184722
# 2287  5/10/2018  2723.070068  125.180000  14.4100  15.7400  1.191753
# 2288  5/14/2018  2730.129883  124.489998  14.3800  15.5600  1.193118
# 2289  5/16/2018  2725.780029  122.543800  14.4058  15.4542  1.182033

# %%
# last 10 rows of the dataframe (Gradient background color)
gold_data.tail(10).style.background_gradient(cmap = 'Blues')
# Out:
# <style type="text/css">
# #T_144dd_row0_col1, #T_144dd_row5_col5 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_144dd_row0_col2, #T_144dd_row5_col2 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_144dd_row0_col3 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_144dd_row0_col4 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_144dd_row0_col5, #T_144dd_row7_col2, #T_144dd_row7_col3, #T_144dd_row7_col4, #T_144dd_row8_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_144dd_row1_col1 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_144dd_row1_col2 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_144dd_row1_col3, #T_144dd_row1_col4, #T_144dd_row3_col1, #T_144dd_row9_col2, #T_144dd_row9_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_144dd_row1_col5, #T_144dd_row3_col2 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_144dd_row2_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_144dd_row2_col2, #T_144dd_row5_col1 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_144dd_row2_col3 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_144dd_row2_col4 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_144dd_row2_col5 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_144dd_row3_col3 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_144dd_row3_col4 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_144dd_row3_col5 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_144dd_row4_col1, #T_144dd_row9_col4 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_144dd_row4_col2 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_144dd_row4_col3 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_144dd_row4_col4 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_144dd_row4_col5 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_144dd_row5_col3 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_144dd_row5_col4 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_144dd_row6_col1, #T_144dd_row6_col2 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_144dd_row6_col3 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_144dd_row6_col4 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_144dd_row6_col5 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_144dd_row7_col1 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_144dd_row7_col5 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_144dd_row8_col2 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_144dd_row8_col3 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_144dd_row8_col4 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_144dd_row8_col5 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_144dd_row9_col1 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_144dd_row9_col3 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_144dd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_144dd_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_144dd_level0_col1" class="col_heading level0 col1" >SPX</th>
#       <th id="T_144dd_level0_col2" class="col_heading level0 col2" >GLD</th>
#       <th id="T_144dd_level0_col3" class="col_heading level0 col3" >USO</th>
#       <th id="T_144dd_level0_col4" class="col_heading level0 col4" >SLV</th>
#       <th id="T_144dd_level0_col5" class="col_heading level0 col5" >EUR/USD</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_144dd_level0_row0" class="row_heading level0 row0" >2280</th>
#       <td id="T_144dd_row0_col0" class="data row0 col0" >4/30/2018</td>
#       <td id="T_144dd_row0_col1" class="data row0 col1" >2648.050049</td>
#       <td id="T_144dd_row0_col2" class="data row0 col2" >124.589996</td>
#       <td id="T_144dd_row0_col3" class="data row0 col3" >13.800000</td>
#       <td id="T_144dd_row0_col4" class="data row0 col4" >15.380000</td>
#       <td id="T_144dd_row0_col5" class="data row0 col5" >1.208123</td>
#     </tr>
#     <tr>
#       <th id="T_144dd_level0_row1" class="row_heading level0 row1" >2281</th>
#       <td id="T_144dd_row1_col0" class="data row1 col0" >5/1/2018</td>
#       <td id="T_144dd_row1_col1" class="data row1 col1" >2654.800049</td>
#       <td id="T_144dd_row1_col2" class="data row1 col2" >123.709999</td>
#       <td id="T_144dd_row1_col3" class="data row1 col3" >13.610000</td>
#       <td id="T_144dd_row1_col4" class="data row1 col4" >15.240000</td>
#       <td id="T_144dd_row1_col5" class="data row1 col5" >1.199156</td>
#     </tr>
#     <tr>
#       <th id="T_144dd_level0_row2" class="row_heading level0 row2" >2282</th>
#       <td id="T_144dd_row2_col0" class="data row2 col0" >5/2/2018</td>
#       <td id="T_144dd_row2_col1" class="data row2 col1" >2635.669922</td>
#       <td id="T_144dd_row2_col2" class="data row2 col2" >123.650002</td>
#       <td id="T_144dd_row2_col3" class="data row2 col3" >13.670000</td>
#       <td id="T_144dd_row2_col4" class="data row2 col4" >15.420000</td>
#       <td id="T_144dd_row2_col5" class="data row2 col5" >1.195100</td>
#     </tr>
#     <tr>
#       <th id="T_144dd_level0_row3" class="row_heading level0 row3" >2283</th>
#       <td id="T_144dd_row3_col0" class="data row3 col0" >5/3/2018</td>
#       <td id="T_144dd_row3_col1" class="data row3 col1" >2629.729980</td>
#       <td id="T_144dd_row3_col2" class="data row3 col2" >124.279999</td>
#       <td id="T_144dd_row3_col3" class="data row3 col3" >13.820000</td>
#       <td id="T_144dd_row3_col4" class="data row3 col4" >15.460000</td>
#       <td id="T_144dd_row3_col5" class="data row3 col5" >1.198926</td>
#     </tr>
#     <tr>
#       <th id="T_144dd_level0_row4" class="row_heading level0 row4" >2284</th>
#       <td id="T_144dd_row4_col0" class="data row4 col0" >5/7/2018</td>
#       <td id="T_144dd_row4_col1" class="data row4 col1" >2672.629883</td>
#       <td id="T_144dd_row4_col2" class="data row4 col2" >124.570000</td>
#       <td id="T_144dd_row4_col3" class="data row4 col3" >14.100000</td>
#       <td id="T_144dd_row4_col4" class="data row4 col4" >15.520000</td>
#       <td id="T_144dd_row4_col5" class="data row4 col5" >1.193374</td>
#     </tr>
#     <tr>
#       <th id="T_144dd_level0_row5" class="row_heading level0 row5" >2285</th>
#       <td id="T_144dd_row5_col0" class="data row5 col0" >5/8/2018</td>
#       <td id="T_144dd_row5_col1" class="data row5 col1" >2671.919922</td>
#       <td id="T_144dd_row5_col2" class="data row5 col2" >124.589996</td>
#       <td id="T_144dd_row5_col3" class="data row5 col3" >14.060000</td>
#       <td id="T_144dd_row5_col4" class="data row5 col4" >15.510000</td>
#       <td id="T_144dd_row5_col5" class="data row5 col5" >1.186789</td>
#     </tr>
#     <tr>
#       <th id="T_144dd_level0_row6" class="row_heading level0 row6" >2286</th>
#       <td id="T_144dd_row6_col0" class="data row6 col0" >5/9/2018</td>
#       <td id="T_144dd_row6_col1" class="data row6 col1" >2697.790039</td>
#       <td id="T_144dd_row6_col2" class="data row6 col2" >124.330002</td>
#       <td id="T_144dd_row6_col3" class="data row6 col3" >14.370000</td>
#       <td id="T_144dd_row6_col4" class="data row6 col4" >15.530000</td>
#       <td id="T_144dd_row6_col5" class="data row6 col5" >1.184722</td>
#     </tr>
#     <tr>
#       <th id="T_144dd_level0_row7" class="row_heading level0 row7" >2287</th>
#       <td id="T_144dd_row7_col0" class="data row7 col0" >5/10/2018</td>
#       <td id="T_144dd_row7_col1" class="data row7 col1" >2723.070068</td>
#       <td id="T_144dd_row7_col2" class="data row7 col2" >125.180000</td>
#       <td id="T_144dd_row7_col3" class="data row7 col3" >14.410000</td>
#       <td id="T_144dd_row7_col4" class="data row7 col4" >15.740000</td>
#       <td id="T_144dd_row7_col5" class="data row7 col5" >1.191753</td>
#     </tr>
#     <tr>
#       <th id="T_144dd_level0_row8" class="row_heading level0 row8" >2288</th>
#       <td id="T_144dd_row8_col0" class="data row8 col0" >5/14/2018</td>
#       <td id="T_144dd_row8_col1" class="data row8 col1" >2730.129883</td>
#       <td id="T_144dd_row8_col2" class="data row8 col2" >124.489998</td>
#       <td id="T_144dd_row8_col3" clas

# %%
# number of rows(2290) and columns(6)
gold_data.shape
# Out:
# (2290, 6)

# %%
# the label of each column in the DataFrame
gold_data.columns
# Out:
# Index(['Date', 'SPX', 'GLD', 'USO', 'SLV', 'EUR/USD'], dtype='object')

# %%
# getting some informations about the dataset
gold_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2290 entries, 0 to 2289
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2290 non-null   object
#  1   SPX      2290 non-null   float64
#  2   GLD      2290 non-null   float64
#  3   USO      2290 non-null   float64
#  4   SLV      2290 non-null   float64
#  5   EUR/USD  2290 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 107.5+ KB

# %%
plt.rcParams['figure.figsize'] = [12, 8]#resize the plot
#plt.figure(figsize = (12, 8))

gold_data.plot()
plt.show()

# %%
# Check for null values
gold_data.isnull().sum()
# Out:
# Date       0
# SPX        0
# GLD        0
# USO        0
# SLV        0
# EUR/USD    0
# dtype: int64

# %%
#Detect missing values
gold_data.isna().sum()
# Out:
# Date       0
# SPX        0
# GLD        0
# USO        0
# SLV        0
# EUR/USD    0
# dtype: int64

# %%
# statistical Measures of the dataset 
gold_data.describe()
# Out:
#                SPX          GLD          USO          SLV      EUR/USD
# count  2290.000000  2290.000000  2290.000000  2290.000000  2290.000000
# mean   1654.315776   122.732875    31.842221    20.084997     1.283653
# std     519.111540    23.283346    19.523517     7.092566     0.131547
# min     676.530029    70.000000     7.960000     8.850000     1.039047
# 25%    1239.874969   109.725000    14.380000    15.570000     1.171313
# 50%    1551.434998   120.580002    33.869999    17.268500     1.303297
# 75%    2073.010070   132.840004    37.827501    22.882500     1.369971
# max    2872.870117   184.589996   117.480003    47.259998     1.598798

# %%
# Transpose index and columns.(Gradient background color)
gold_data.describe().T.style.background_gradient(cmap = 'Blues')
# Out:
# <style type="text/css">
# #T_5e444_row0_col0, #T_5e444_row1_col0, #T_5e444_row2_col0, #T_5e444_row3_col0, #T_5e444_row4_col0, #T_5e444_row4_col1, #T_5e444_row4_col2, #T_5e444_row4_col3, #T_5e444_row4_col4, #T_5e444_row4_col5, #T_5e444_row4_col6, #T_5e444_row4_col7 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_5e444_row0_col1, #T_5e444_row0_col2, #T_5e444_row0_col3, #T_5e444_row0_col4, #T_5e444_row0_col5, #T_5e444_row0_col6, #T_5e444_row0_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_5e444_row1_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_5e444_row1_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_5e444_row1_col3 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_5e444_row1_col4 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_5e444_row1_col5 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_5e444_row1_col6, #T_5e444_row1_col7 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_5e444_row2_col1, #T_5e444_row2_col6, #T_5e444_row3_col7 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_5e444_row2_col2 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_5e444_row2_col3, #T_5e444_row2_col4, #T_5e444_row3_col1, #T_5e444_row3_col3, #T_5e444_row3_col4, #T_5e444_row3_col5, #T_5e444_row3_col6 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_5e444_row2_col5 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_5e444_row2_col7 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_5e444_row3_col2 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# </style>
# <table id="T_5e444">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e444_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_5e444_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_5e444_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_5e444_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_5e444_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_5e444_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_5e444_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_5e444_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e444_level0_row0" class="row_heading level0 row0" >SPX</th>
#       <td id="T_5e444_row0_col0" class="data row0 col0" >2290.000000</td>
#       <td id="T_5e444_row0_col1" class="data row0 col1" >1654.315776</td>
#       <td id="T_5e444_row0_col2" class="data row0 col2" >519.111540</td>
#       <td id="T_5e444_row0_col3" class="data row0 col3" >676.530029</td>
#       <td id="T_5e444_row0_col4" class="data row0 col4" >1239.874969</td>
#       <td id="T_5e444_row0_col5" class="data row0 col5" >1551.434998</td>
#       <td id="T_5e444_row0_col6" class="data row0 col6" >2073.010070</td>
#       <td id="T_5e444_row0_col7" class="data row0 col7" >2872.870117</td>
#     </tr>
#     <tr>
#       <th id="T_5e444_level0_row1" class="row_heading level0 row1" >GLD</th>
#       <td id="T_5e444_row1_col0" class="data row1 col0" >2290.000000</td>
#       <td id="T_5e444_row1_col1" class="data row1 col1" >122.732875</td>
#       <td id="T_5e444_row1_col2" class="data row1 col2" >23.283346</td>
#       <td id="T_5e444_row1_col3" class="data row1 col3" >70.000000</td>
#       <td id="T_5e444_row1_col4" class="data row1 col4" >109.725000</td>
#       <td id="T_5e444_row1_col5" class="data row1 col5" >120.580002</td>
#       <td id="T_5e444_row1_col6" class="data row1 col6" >132.840004</td>
#       <td id="T_5e444_row1_col7" class="data row1 col7" >184.589996</td>
#     </tr>
#     <tr>
#       <th id="T_5e444_level0_row2" class="row_heading level0 row2" >USO</th>
#       <td id="T_5e444_row2_col0" class="data row2 col0" >2290.000000</td>
#       <td id="T_5e444_row2_col1" class="data row2 col1" >31.842221</td>
#       <td id="T_5e444_row2_col2" class="data row2 col2" >19.523517</td>
#       <td id="T_5e444_row2_col3" class="data row2 col3" >7.960000</td>
#       <td id="T_5e444_row2_col4" class="data row2 col4" >14.380000</td>
#       <td id="T_5e444_row2_col5" class="data row2 col5" >33.869999</td>
#       <td id="T_5e444_row2_col6" class="data row2 col6" >37.827501</td>
#       <td id="T_5e444_row2_col7" class="data row2 col7" >117.480003</td>
#     </tr>
#     <tr>
#       <th id="T_5e444_level0_row3" class="row_heading level0 row3" >SLV</th>
#       <td id="T_5e444_row3_col0" class="data row3 col0" >2290.000000</td>
#       <td id="T_5e444_row3_col1" class="data row3 col1" >20.084997</td>
#       <td id="T_5e444_row3_col2" class="data row3 col2" >7.092566</td>
#       <td id="T_5e444_row3_col3" class="data row3 col3" >8.850000</td>
#       <td id="T_5e444_row3_col4" class="data row3 col4" >15.570000</td>
#       <td id="T_5e444_row3_col5" class="data row3 col5" >17.268500</td>
#       <td id="T_5e444_row3_col6" class="data row3 col6" >22.882500</td>
#       <td id="T_5e444_row3_col7" class="data row3 col7" >47.259998</td>
#     </tr>
#     <tr>
#       <th id="T_5e444_level0_row4" class="row_heading level0 row4" >EUR/USD</th>
#       <td id="T_5e444_row4_col0" class="data row4 col0" >2290.000000</td>
#       <td id="T_5e444_row4_col1" class="data row4 col1" >1.283653</td>
#       <td id="T_5e444_row4_col2" class="data row4 col2" >0.131547</td>
#       <td id="T_5e444_row4_col3" class="data row4 col3" >1.039047</td>
#       <td id="T_5e444_row4_col4" class="data row4 col4" >1.171313</td>
#       <td id="T_5e444_row4_col5" class="data row4 col5" >1.303297</td>
#       <td id="T_5e444_row4_col6" class="data row4 col6" >1.369971</td>
#       <td id="T_5e444_row4_col7" class="data row4 col7" >1.598798</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **we will not use the colum of date becouse our data does not depend on it.
# so we will deal with the other missing values.**

# %%
# drop the "date",after the cor
data = gold_data.drop(['Date'], axis=1)

# %%
#To check for duplicates
data.duplicated().sum()
# Out:
# 0

# %%
# Check for null values
data.isnull().sum()
# Out:
# SPX        0
# GLD        0
# USO        0
# SLV        0
# EUR/USD    0
# dtype: int64

# %% [markdown]
# **visualization**

# %%
#checking the distribution of the Gold Price.about outliers
sns.displot(data['USO'], color='green')
plt.title('USO Distribution')
plt.xlabel('USO Price')
plt.ylabel('Occurrences')
plt.show()

# %%
q = data["USO"].quantile(0.98)
data[data["USO"] > q]
data = data[(data["USO"] < q)]

# %%
#checking the distribution of the Gold Price.about outliers
sns.displot(data['USO'], color='green')
plt.title('USO Distribution')
plt.xlabel('USO Price')
plt.ylabel('Occurrences')
plt.show()

# %%
#checking the distribution of the Gold Price.about outliers
sns.displot(data['SPX'], color='blue')
plt.title('SPX Distribution')
plt.xlabel('SPX Price')
plt.ylabel('Occurrences')
plt.show()

# %%
#checking the distribution of the Gold Price.about outliers
sns.displot(data['GLD'], color='gold')
plt.title('Gold Distribution')
plt.xlabel('Gold Price')
plt.ylabel('Occurrences')
plt.show()

# %%
#checking the distribution of the Gold Price.about outliers
sns.displot(data['SLV'], color='silver')
plt.title('SLV Distribution')
plt.xlabel('SLV Price')
plt.ylabel('Occurrences')
plt.show()

# %%
#checking the distribution of the Gold Price.about outliers
sns.displot(data['EUR/USD'], color='cyan')
plt.title('EUR/USD exchange-rate Distribution')
plt.xlabel('EUR/USD exchange-rate')
plt.ylabel('Occurrences')
plt.show()

# %% [markdown]
# **Correlation**

# %%
# Compute pairwise correlation of columns 
# to identity the highly correlated features.
correlation = data.corr()

# %%
# Construct a heatmap to undestand the correlation
plt.figure(figsize= (8,8))
sns.heatmap(correlation, cbar=True, square=True, fmt='.2f', annot=True, annot_kws={'size':10}, cmap='Greens')
# Out:
# <Axes: >

# %%
# correlation values of Gold
print(correlation['GLD'])
# Out:
# SPX        0.032141
# GLD        1.000000
# USO       -0.091204
# SLV        0.874769
# EUR/USD    0.040271
# Name: GLD, dtype: float64

# %% [markdown]
# Splitting the data into a Training dataset & Testing dataset

# %%
# discard the gold and use the rest values as features
X = data.drop(['GLD'], axis=1)

# use the gold as the target
Y = data['GLD']

# %%
# The Features (input)
X
# The Features (input)(Gradient background color)
#X.style.background_gradient(cmap='Reds')
# Out:
#               SPX        USO      SLV   EUR/USD
# 0     1447.160034  78.470001  15.1800  1.471692
# 1     1447.160034  78.370003  15.2850  1.474491
# 2     1411.630005  77.309998  15.1670  1.475492
# 3     1416.180054  75.500000  15.0530  1.468299
# 4     1390.189941  76.059998  15.5900  1.557099
# ...           ...        ...      ...       ...
# 2285  2671.919922  14.060000  15.5100  1.186789
# 2286  2697.790039  14.370000  15.5300  1.184722
# 2287  2723.070068  14.410000  15.7400  1.191753
# 2288  2730.129883  14.380000  15.5600  1.193118
# 2289  2725.780029  14.405800  15.4542  1.182033
#
# [2244 rows x 4 columns]

# %%
# The target
Y
# The target(Gradient background color)
#Y.style.background_gradient(cmap='Reds')
# Out:
# 0        84.860001
# 1        85.570000
# 2        85.129997
# 3        84.769997
# 4        86.779999
#            ...
# 2285    124.589996
# 2286    124.330002
# 2287    125.180000
# 2288    124.489998
# 2289    122.543800
# Name: GLD, Length: 2244, dtype: float64

# %%
# Split arrays or matrices into random train and test subsets
#random_state #Testing the model with 20% of the dataset & training it with 80% of the model
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size= 0.2, random_state=0)

# %% [markdown]
# **Model Training: Random Forest Regressor**

# %%
regressor = RandomForestRegressor(n_estimators=100)

# %%
regressor
# Out:
# RandomForestRegressor()

# %%
# training the model
regressor.fit(X_train, Y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# Evalutation

# %%
# prediction on Test Data
test_data_prediction = regressor.predict(X_test)

# %%
print(test_data_prediction)
# Out:
# [ 86.27559961 104.49109788 127.1770972  132.12450108  95.87989984
#  125.59270148 165.4824011   91.69459895  75.88179884 120.26590071
#  146.60439737 126.92889963 125.47059936 116.29489839 133.60680235
#  102.83489917 107.10389977 133.82860127  87.85629896 139.06329975
#  112.29089993 124.64300058 117.46260023 114.28160101 117.1617005
#  120.37890204 160.15899908 119.15480006 156.54330177 146.05180087
#  117.78059955 118.74820119  88.09360045 160.55909774 147.93839918
#  117.95910048 109.86550051 111.33230073 160.32199643 111.74429917
#  140.87969867 115.22430056 123.18619948  72.52380168 126.20119967
#  168.21159912 108.16360056 107.41980091 125.37530005 153.73890119
#   94.1354997  160.2932963   90.93639895 112.72840156 109.69619735
#   84.24829993 156.89919931 156.10620286 127.96140047 172.22559821
#  165.52700183 124.10899896 107.73710074  79.22169996 118.81639907
#  129.121099    93.62259914 154.53460165 125.75160185 137.81370423
#  125.59390114 100.41149877 124.0189013  114.33820055 171.16550118
#  120.6800761  120.30619986 116.5500011  117.72529943 136.40239959
#   77.95809926 117.14559963 122.40440355 159.25350008 122.77240044
#  144.56859801 119.22060012 113.5903015  125.6158993   91.57630058
#  162.86800262 112.65110032 121.00940066  84.07439807 108.29089878
#  121.16160092 145.8278022  128.67930105 128.0357986   87.39580045
#  105.51449954 133.46820259 120.2677016  132.46349892 118.53210021
#  117.46189955 159.54290232 122.56959987 154.43450182  92.41919918
#  123.60360049 156.03430373 117.48570109 119.54869905 108.65489919
#  148.03500219 163.29110124  92.0924012  121.57380166  94.57310055
#   90.7325999  125.59670031 106.68879887 117.38690093 146.5580009
#  153.22890299 115.62899919 155.38520126  88.32209883 170.95850227
#  124.71590038 122.43150087 113.76300049 121.32420037 126.82379773
#  113.06160086 140.19259921 154.82159988 120.8739998  125.99830069
#  117.08170099 176.38119724  95.79620119 119.97659977 123.40100093
#  163.77399883 120.54319929 110.79849889  97.35119861 119.22169973
#  101.95329968 102.16539933  91.54019869 126.71010045 125.27700019
#  115.84490044 118.81530042 167.70989843 136.55120525 153.12350244
#  126.15230002 113.23249987 101.61470026 114.65969879  92.0329002
#  132.43210118 167.686199   124.69099852 125.54789996 119.19200035
#  121.05251352 119.30789991 107.93890102  90.74460009 118.94609869
#  117.8381005  123.68739891 121.70779988 114.38420022 137.34489967
#   90.73520089 108.11669938 116.41770032 140.74529981 120.60370006
#  113.65183787 118.88969993  97.70909906 126.18029957 116.8258012
#  128.23259971 165.30780059 114.78749892  72.82150126 153.67810078
#  141.2738005  127.5355967  135.13190156 139.10350156 118.81089987
#  158.89289924 165.70419809 157.67470507 127.61630015 118.13050037
#  125.11479993 168.10259952 127.89270034 122.15453825 140.01570106
#  159.9539012   93.24849892 117.62080019 156.48080081 113.69590013
#  110.47439815 155.77139923 118.17869871 119.03000124 113.76690056
#  118.08149901 122.98369939  82.33539902 116.83580058 152.19749975
#  155.64510009 124.89579997 114.82799997  89.72799969  87.59829834
#   91.71889859 104.05219889 109.39469914 111.38839963 116.79290106
#  143.06500049 117.31900082 114.50060102  96.18550065 116.36540078
#   88.83409983 126.62470091 114.46619964 106.46039886  88.4173993
#   99.35540078  83.45369955 103.86209809 131.1689018  121.59700021
#  160.83570155 102.97059836  89.90519958 127.89629882 149.36829822
#  107.09959995 124.14203859 120.64870066 115.28989911  75.62909986
#  125.59050026 109.31599862 120.83250039 111.8975003   93.63169908
#  125.33690018 120.90900175 110.39119816 109.57469945 159.59099917
#  112.56420113 158.83150022 121.29230028  95.42090128  89.74000116
#  139.19820106 114.98179981 119.60780037 127.60910004 126.31189917
#  104.27929831 126.89600001 115.77149943 114.95700049 107.08450024
#   91.49320083 121.58400044 125.62219887 118.65410049 122.13210077
#   80.74799977 135.18069817 126.0233007  167.05210108 127.82029805
#  120.48579946 115.52339921 149.36389944 104.93519799 124.34540138
#  119.71469917  87.73540045 132.20579924 132.36990095 122.61130049
#   92.69950001 134.65949995 117.2474003  120.75880173 126.38829977
#  161.1089009  109.20349985 134.7151006   84.49409978  93.22339876
#   90.6897984  114.99969988 108.71450092 132.5746998  118.06779892
#  122.07990078 128.38260191 125.96590175 133.01590348 120.12090085
#  159.56800093 115.7683     107.47559988 136.98769634 127.70959963
#  173.2878982  111.64230025 165.83239632 114.63210029 111.35219943
#  143.90980144 111.18159899 155.98440209 128.10640133 114.20089842
#  112.22029952 155.66920002 127.05739697  88.89029982  92.84370001
#  113.50610015 134.12120152 118.71170141  90.5626998  164.72739752
#  116.62840165 120.33350096 113.91100015 102.52769932 124.91969905
#  125.26110035 137.95030063 127.20940086  87.84109875 120.11250028
#  166.8702974  114.74993866 134.66970001 110.98509902 122.8256011
#  107.58040122 120.42109881 100.10880138 116.30390034 127.35909872
#  156.68470087 163.34220209  92.51379937 121.93420034 109.15290108
#   96.24179952 119.54580115 126.15990069 126.32719974 120.81370036
#   88.08110101  93.51719809 113.01160068 115.89089816 152.70670121
#  106.30120051 113.17370098 113.76679914 120.5415004  100.91909823
#  131.51189919 132.56280068 128.23140033 157.0772012  149.44629863
#  119.03169967  90.09170118 102.69579902 117.75639914 115.2618998
#  131.85440124 166.91570143 128.72409819 154.96020133 103.35249945
#  116.59779945 144.37409992 117.77579914 117.82899967 108.74379923
#  118.36669898  92.35419974 141.11310295 112.26130081 114.78880051
#  129.36899909  94.06709937 124.80250135 120.66260013 123.90250031
#  120.0105008  165.90590251 154.5186992  156.7116027  119.31930109
#  114.02130067 128.00640064 160.32460202 167.7522016  126.45829913
#   76.62599896 120.71000017 123.71279884 117.9609015  114.99160023
#  129.94130088  88.29979988  98.50309918 117.14680007 128.08370062
#   86.67649909 115.61650019 111.82469975 159.45330195  94.31749971
#  116.85120109 116.76679998  88.04010027 132.27100283]

# %%
# R Squared error
error_score = metrics.r2_score(Y_test, test_data_prediction) # coefficient of determination, regression score function.
print('R squared error : ', error_score)
# Out:
# R squared error :  0.9885347125810031

# %% [markdown]
# **Compare the Actual Values and Predicted Values in a Plot**

# %%
Y_test = np.array(Y_test)
#Y_test = list(Y_test) #Converting the actual values to a list,so that it can be in the same format as the test_data_prediction

# %%
plt.rcParams['figure.figsize'] = [10, 8]#resize the plot
plt.plot(Y_test, color='blue', label='Actual Value')
plt.title('Actual Price vs Predicted Price')
plt.xlabel('Number of values')
plt.ylabel('Golden Price')
plt.legend()
plt.show()

# %%
plt.plot(test_data_prediction, color='red', label='Predicted value')
plt.title('Actual Price vs Predicted Price')
plt.xlabel('Number of values')
plt.ylabel('Golden Price')
plt.legend()
plt.show()

# %%
plt.plot(Y_test, color='blue', label='Actual Value')
plt.plot(test_data_prediction, color='red', label='Predicted value')
plt.title('Actual Price vs Predicted Price')
plt.xlabel('Number of values')
plt.ylabel('Golden Price')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (12,8))
plt.hist(Y_test, color='purple', label = 'Actual Value')
plt.hist(test_data_prediction, color='green', label='Predicted Value')
plt.title('Actual Price of Gold vs Predicted Price of Gold')
plt.xlabel('Number of values')
plt.ylabel('GOLD Price', rotation=30)
plt.legend()
plt.show()
